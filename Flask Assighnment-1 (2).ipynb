# %% [markdown]
# # Flask Assighnment-1

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a simple web framework for Python. Its advantages are being lightweight, easy to start with, flexible, and extensible with a large community support. It's great for building web apps and APIs.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from IPython import display
display.Image("Hello.png")

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing in Flask is the process of mapping URLs (routes) to specific functions that handle the incoming requests. We use app routes to define the different pages or endpoints of our web application, allowing users to access and interact with different parts of the application through specific URLs.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# * Company Name: ABC Corporation
# * Location: India
# * Contact Detail: 999-999-9999
# ### Attach the Screenshot of the output

# %%
from IPython import display
display.Image("Welcome.png")

# %%
from IPython import display
display.Image("Column.png")

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. It helps generate URLs for specific routes in your application, making it easier to handle dynamic URLs and maintain consistency.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def index():
    # Using url_for() to generate the URL for the 'welcome' route
    welcome_url = url_for('welcome')
    return f'Visit the welcome page: {welcome_url}'

if __name__ == '__main__':
    app.run()
